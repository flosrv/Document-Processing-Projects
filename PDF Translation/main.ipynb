# %%
import os, re
import fitz as pymupdf
from deep_translator import GoogleTranslator
from operator import itemgetter
from pdf2docx import Converter
import docx

# %%
# === Configuration ===
doc_folder = r"c:\Users\f.gionnane\Documents\Document Processing Projects\PDF Translation"
file_name = "Charles-Gave-Un-Libéral-Nommé-Jésus.pdf"
filename_without_extension = os.path.splitext(file_name)[0]
path_to_doc = os.path.join(doc_folder, file_name)

target_es = "es"
es_translator = GoogleTranslator(source='auto', target=target_es)

# === Ouvrir le document PDF ===
doc = pymupdf.open(path_to_doc)

# %%
print("Processing...")

# Track the progress with print statements
for page_num, page in enumerate(doc, start=1):
    print(f"Processing page {page_num}/{len(doc)}...")
    
    blocks = page.get_text("blocks", flags=pymupdf.TEXT_DEHYPHENATE)
    
    for block_num, block in enumerate(blocks, start=1):
        bbox = block[:4]
        original = block[4]
        
        print(f"  Processing block {block_num}/{len(blocks)} on page {page_num}...")

        # Translate and ensure it's a string
        translated = str(es_translator.translate(original))  # Ensure it's a string
        
        # Check if translation is successful
        if translated:
            print(f"    Translation successful: {translated[:30]}...")  # Print part of translation for verification
        else:
            print(f"    Translation failed or is empty for block {block_num}")

        # Clear the original block's area and insert the translated text
        page.draw_rect(bbox, color=None, fill=pymupdf.pdfcolor["white"])
        page.insert_htmlbox(bbox, translated)

# Output file path
output_path = os.path.join(doc_folder, f"{filename_without_extension}_{target_es}.pdf")
print(f"Saving translated document to {output_path}...")

# Save the document
doc.save(output_path)

print("Processing complete!")

# %% [markdown]
# test

# %%
print("📄 Début du traitement du document...")

# === Créer le fichier texte pour le suivi ===
txt_output_path = os.path.join(doc_folder, f"{filename_without_extension}_{target_es}_draft.txt")
with open(txt_output_path, "w", encoding="utf-8") as txt_file:
    txt_file.write(f"Traduction du document : {file_name} vers [{target_es}]\n\n")

# === Fonction pour regrouper les blocs en paragraphes ===
def group_blocks_by_y(blocks, y_threshold=5):
    blocks.sort(key=itemgetter(1))  # Trier selon la coordonnée Y (top)
    grouped = []
    current_group = []
    last_bottom = 0

    for block in blocks:
        top = block[1]
        if not current_group or top - last_bottom <= y_threshold:
            current_group.append(block)
            last_bottom = block[3]
        else:
            grouped.append(current_group)
            current_group = [block]
            last_bottom = block[3]

    if current_group:
        grouped.append(current_group)

    return grouped

# === Fonction pour nettoyer le texte corrompu ===
def clean_text(text):
    # Enlever les caractères non valides ou corrompus (comme les caractères '�')
    # Cela va remplacer les caractères indésirables par des espaces ou les ignorer
    cleaned = re.sub(r'[^\x00-\x7F]+', '', text)  # Supprime les caractères non-ASCII
    return cleaned

# === Traitement des pages ===
for page_num, page in enumerate(doc, start=1):
    print(f"\n➡️  Page {page_num}/{len(doc)} en cours...")

    blocks = page.get_text("blocks", flags=pymupdf.TEXT_DEHYPHENATE)
    paragraph_groups = group_blocks_by_y(blocks)

    with open(txt_output_path, "a", encoding="utf-8") as txt_file:
        txt_file.write(f"\n{'='*40}\nPage {page_num}\n{'='*40}\n")

    for group_num, block_group in enumerate(paragraph_groups, start=1):
        paragraph_text = " ".join(block[4].strip() for block in block_group if block[4].strip())
        if not paragraph_text:
            continue

        # Nettoyer le texte corrompu
        cleaned_text = clean_text(paragraph_text)

        # Si après nettoyage, le texte est vide (c'est-à-dire corrompu ou illisible), on l'ignore
        if not cleaned_text.strip():
            print(f"    ⚠️ Paragraphe {group_num} ignoré, texte corrompu ou illisible.")
            continue

        print(f"  ↪️ Paragraphe {group_num} : {cleaned_text[:50]}...")

        try:
            translated = str(es_translator.translate(cleaned_text))
            if not translated.strip():
                print(f"    ⚠️ Traduction vide")
                continue
        except Exception as e:
            print(f"    ❌ Erreur de traduction : {e}")
            continue

        print(f"    ✅ Traduction : {translated[:50]}...")

        # Écrire uniquement la traduction dans le fichier texte
        with open(txt_output_path, "a", encoding="utf-8") as txt_file:
            txt_file.write(f"\n--- Paragraphe {group_num} ---\n")
            txt_file.write(f"[Traduction]\n{translated}\n")

        # Calculer la bbox englobante
        x0 = min(block[0] for block in block_group)
        y0 = min(block[1] for block in block_group)
        x1 = max(block[2] for block in block_group)
        y1 = max(block[3] for block in block_group)
        padding = 1
        bbox = (x0 + padding, y0 + padding, x1 - padding, y1 - padding)

        # Nettoyage + insertion dans le PDF
        page.draw_rect(bbox, color=None, fill=pymupdf.pdfcolor["white"])
        page.insert_htmlbox(bbox, translated)

# === Sauvegarde finale du PDF ===
output_path = os.path.join(doc_folder, f"{filename_without_extension}_{target_es}.pdf")
print(f"\n💾 Sauvegarde du PDF traduit dans :\n{output_path}")
doc.save(output_path)

print(f"\n📝 Texte de traduction temporaire dans :\n{txt_output_path}")
print("✅ Traitement terminé !")

# %% [markdown]
# Test tranlate with docx conversion

# %%
import os
from pdf2docx import Converter

# Chemin du PDF et du DOCX
doc_folder = r"c:\Users\f.gionnane\Documents\Document Processing Projects\PDF Translation"
file_name = "Charles-Gave-Un-Libéral-Nommé-Jésus.pdf"  # Remplacez par le nom de votre fichier PDF
filename_without_extension = os.path.splitext(file_name)[0]

# Chemin complet pour le fichier PDF et le fichier DOCX converti
pdf_path = os.path.join(doc_folder, file_name)
docx_path = os.path.join(doc_folder, f"{filename_without_extension}.docx")

# Convertir le PDF en DOCX
cv = Converter(pdf_path)
cv.convert(docx_path, start=0, end=None)

print(f"Le fichier PDF a été converti en DOCX et sauvegardé sous : {docx_path}")

# %%
import os
import docx
from deep_translator import GoogleTranslator

# Initialiser le traducteur
target_es = "es"
es_translator = GoogleTranslator(source='auto', target=target_es)
print(f"Traducteur initialisé pour traduire en {target_es}.")

# Chemin du fichier DOCX
docx_path = os.path.join(doc_folder, f"{filename_without_extension}.docx")
print(f"Chargement du document DOCX à partir de : {docx_path}")
doc = docx.Document(docx_path)
print(f"Document DOCX chargé avec {len(doc.paragraphs)} paragraphes.")

# Chemin du fichier TXT pour prévisualiser la traduction
txt_preview_path = os.path.join(doc_folder, f"{filename_without_extension}_{target_es}_preview.txt")

# Créer/vider le fichier texte avant d’écrire dedans
with open(txt_preview_path, "w", encoding="utf-8") as preview_file:
    preview_file.write(f"Prévisualisation de la traduction en espagnol de : {file_name}\n\n")

# Traduction du texte dans le DOCX
for index, para in enumerate(doc.paragraphs, start=1):
    original_text = para.text.strip()

    if original_text:
        print(f"[{index}] Traduction du texte : {original_text[:50]}...")
        try:
            translated_text = es_translator.translate(original_text)
            para.text = translated_text

            # Écriture dans le fichier .txt
            with open(txt_preview_path, "a", encoding="utf-8") as preview_file:
                preview_file.write(translated_text + "\n")

            print(f"[{index}] ✅ Texte traduit ajouté au fichier .txt")

        except Exception as e:
            print(f"[{index}] ❌ Erreur de traduction : {e}")
    else:
        print(f"[{index}] (Paragraphe vide ignoré)")

# Sauvegarde du document DOCX traduit
docx_output_path = os.path.join(doc_folder, f"{filename_without_extension}_{target_es}.docx")
doc.save(docx_output_path)
print(f"\n✅ Le document traduit a été sauvegardé sous : {docx_output_path}")
print(f"📄 Fichier de prévisualisation disponible ici : {txt_preview_path}")
# Out:
# Traducteur initialisé pour traduire en es.
# Chargement du document DOCX à partir de : c:\Users\f.gionnane\Documents\Document Processing Projects\PDF Translation\Charles-Gave-Un-Libéral-Nommé-Jésus.docx
# Document DOCX chargé avec 1380 paragraphes.
# [1] Traduction du texte : Charles Gave
# Un Libéral Nommé Jésus Parabole Écon...
# [1] ✅ Texte traduit ajouté au fichier .txt
# [2] Traduction du texte : 1...
# [2] ✅ Texte traduit ajouté au fichier .txt
# [3] (Paragraphe vide ignoré)
# [4] (Paragraphe vide ignoré)
# [5] (Paragraphe vide ignoré)
# [6] (Paragraphe vide ignoré)
# [7] Traduction du texte : Cet ouvrage vous est offert par :...
# [7] ✅ Texte traduit ajouté au fichier .txt
# [8] (Paragraphe vide ignoré)
# [9] (Paragraphe vide ignoré)
# [10] (Paragraphe vide ignoré)
# [11] Traduction du texte : Sommaire...
# [11] ✅ Texte traduit ajouté au fichier .txt
# [12] Traduction du texte : AVANT-PROPOS 	 p.7 Nous sommes des nains sur les é...
# [12] ✅ Texte traduit ajouté au fichier .txt
# [13] Traduction du texte : CHAPITRE I 	 p.21 Tout commence par un coup de fou...
# [13] ✅ Texte traduit ajouté au fichier .txt
# [14] Traduction du texte : CHAPITRE II 	 p.33 Le patient socialiste est mort,...
# [14] ✅ Texte traduit ajouté au fichier .txt
# [15] Traduction du texte : CHAPITRE III 	 p.51 Une idée à mettre en œuvre tou...
# [15] ✅ Texte traduit ajouté au fichier .txt
# [16] Traduction du texte : CHAPITRE IV 	 p.61 Les Evangiles et la prise de ri...
# [16] ✅ Texte traduit ajouté au fichier .txt
# [17] Traduction du texte : CHAPITRE V 	 p.69 Les évangiles et la notion de va...
# [17] ✅ Texte traduit ajouté au fichier .txt
# [18] Traduction du texte : CHAPITRE VI 	 p.81 Les Evangiles et la richesse...
# [18] ✅ Texte traduit ajouté au fichier .txt
# [19] Traduction du texte : CHAPITRE VII 	 p.94 Les Evangiles et la justice so...
# [19] ✅ Texte traduit ajouté au fichier .txt
# [20] Traduction du texte : CHAPITRE VIII 	 p.107 Les Evangiles, le travail et...
# [20] ✅ Texte traduit ajouté au fichier .txt
# [21] (Paragraphe vide ignoré)
# [22] (Paragraphe vide ignoré)
# [23] (Paragraphe vide ignoré)
# [24] Traduction du texte : Les Evangiles, la défense, l'illustration du capit...
# [24] ✅ Texte traduit ajouté au fichier .txt
# [25] Traduction du texte : CHAPITRE X 	 p.133 Evangiles, investissement et re...
# [25] ✅ Texte traduit ajouté au fichier .txt
# [26] Traduction du texte : CHAPITRE XI 	 p.141 Evangiles et endettement...
# [26] ✅ Texte traduit ajouté au fichier .txt
# [27] Traduction du texte : CHAPITRE XII 	 p.147 Les Evangiles et le contrat...
# [27] ✅ Texte traduit ajouté au fichier .txt
# [28] Traduction du texte : CONCLUSION 	 p.157 Quand un rocher change le cours...
# [28] ✅ Texte traduit ajouté au fichier .txt
# [29] (Paragraphe vide ignoré)
# [30] (Paragraphe vide ignoré)
# [31] (Paragraphe vide ignoré)
# [32] (Paragraphe vide ignoré)
# [33] (Paragraphe vide ignoré)
# [34] (Paragraphe vide ignoré)
# [35] Traduction du texte : Avant Propos...
# [35] ✅ Texte traduit ajouté au fichier .txt
# [36] Traduction du texte : Nous sommes des nains sur les épaules de géants...
# [36] ✅ Texte traduit ajouté au fichier .txt
# [37] Traduction du texte : On peut s'étonner qu'un économiste se penche sur l...
# [37] ✅ Texte traduit ajouté au fichier .txt
# [38] Traduction du texte : A observer le monde dans lequel nous vivons, je re...
# [38] ✅ Texte traduit ajouté au fichier .txt
# [39] Traduction du texte : Je crois qu'à l’origine de notre civilisation, il ...
# [39] ✅ Texte traduit ajouté au fichier .txt
# [40] Traduction du texte : 1 La phrase est de Newton
# 2 Des Lions menés par d...
# [40] ✅ Texte traduit ajouté au fichier .txt
# [41] Traduction du texte : 7...
# [41] ✅ Texte traduit ajouté au fichier .txt
# [42] (Paragraphe vide ignoré)
# [43] Traduction du texte : Bretagne, puis ailleurs, avait permis l’extraordin...
# [43] ✅ Texte traduit ajouté au fichier .txt
# [44] Traduction du texte : J'ai cherché aussi à démontrer comment l’abandon a...
# [44] ✅ Texte traduit ajouté au fichier .txt
# [45] Traduction du texte : Dans ce second essai, je souhaite compléter cette ...
# [45] ✅ Texte traduit ajouté au fichier .txt
# [46] Traduction du texte : Nous le savons tous : "L'homme ne vit pas que de p...
# [46] ✅ Texte traduit ajouté au fichier .txt
# [47] Traduction du texte : En d'autres termes, les Grecs sans le Christ ne mè...
# [47] ✅ Texte traduit ajouté au fichier .txt
# [48] Traduction du texte : 3 Ce désastre est bien entamé : je ne changerai pa...
# [48] ✅ Texte traduit ajouté au fichier .txt
# [49] (Paragraphe vide ignoré)
# [50] (Paragraphe vide ignoré)
# [51] Traduction du texte : tous devant Dieu ne mène qu'à la connaissance sans...
# [51] ✅ Texte traduit ajouté au fichier .txt
# [52] Traduction du texte : La liberté sans l’égalité devant Dieu mène à l’esc...
# [52] ✅ Texte traduit ajouté au fichier .txt
# [53] Traduction du texte : Or cette éthique, ces codes de lecture du monde, c...
# [53] ✅ Texte traduit ajouté au fichier .txt
# [54] Traduction du texte : J'entends déjà une première objection : mais enfin...
# [54] ✅ Texte traduit ajouté au fichier .txt
# [55] Traduction du texte : Peut être....
# [55] ✅ Texte traduit ajouté au fichier .txt
# [56] Traduction du texte : Que l’on me permette à ce sujet, de raconter une p...
# [56] ✅ Texte traduit ajouté au fichier .txt
# [57] Traduction du texte : Toulouse avait été bâtie sur des marais au temps d...
# [57] ✅ Texte traduit ajouté au fichier .txt
# [58] Traduction du texte : 9...
# [58] ✅ Texte traduit ajouté au fichier .txt
# [59] (Paragraphe vide ignoré)
# [60] Traduction du texte : canalisations fonctionnaient toujours, mais tout l...
# [60] ✅ Texte traduit ajouté au fichier .txt
# [61] Traduction du texte : Si d'aucuns veulent mettre en avant une morale nou...
# [61] ✅ Texte traduit ajouté au fichier .txt
# [62] Traduction du texte : Ne pas prendre en compte le rôle des religions dan...
# [62] ✅ Texte traduit ajouté au fichier .txt
# [63] Traduction du texte : En fait, j'imagine notre civilisation comme un lin...
# [63] ✅ Texte traduit ajouté au fichier .txt
# [64] Traduction du texte : 4 Pour ceux que l’étude des civilisations intéress...
# [64] ✅ Texte traduit ajouté au fichier .txt
# [65] Traduction du texte : 10...
# [65] ✅ Texte traduit ajouté au fichier .txt
# [66] (Paragraphe vide ignoré)
# [67] Traduction du texte : Sous ce linteau, depuis deux mille ans, tous les p...
# [67] ✅ Texte traduit ajouté au fichier .txt
# [68] Traduction du texte : Dans Des lions menés par des ânes, j'avais choisi ...
# [68] ✅ Texte traduit ajouté au fichier .txt
# [69] Traduction du texte : Devant les réactions  à ce pamphlet, j'ai compris ...
# [69] ✅ Texte traduit ajouté au fichier .txt
# [70] Traduction du texte : Mais analyser et dénoncer cette évolution est beau...
# [70] ✅ Texte traduit ajouté au fichier .txt
# [71] Traduction du texte : Antigone désobéit, et elle paie de sa vie sa trans...
# [71] ✅ Texte traduit ajouté au fichier .txt
# [72] Traduction du texte : 5 Le livre s’est très bien vendu. Personne n'en a ...
# [72] ✅ Texte traduit ajouté au fichier .txt
# [73] Traduction du texte : 11...
# [73] ✅ Texte traduit ajouté au fichier .txt
# [74] (Paragraphe vide ignoré)
# [75] Traduction du texte : Sans cette référence à une morale universelle nous...
# [75] ✅ Texte traduit ajouté au fichier .txt
# [76] Traduction du texte : Briser la norme sans en payer le prix est devenu l...
# [76] ✅ Texte traduit ajouté au fichier .txt
# [77] Traduction du texte : Tant et si bien que nous vivons dans une société o...
# [77] ✅ Texte traduit ajouté au fichier .txt
# [78] Traduction du texte : J'aurai donc besoin de toute l’indulgence des lect...
# [78] ✅ Texte traduit ajouté au fichier .txt
# [79] Traduction du texte : Quelques points de méthodologie et l'articulation ...
# [79] ✅ Texte traduit ajouté au fichier .txt
# [80] Traduction du texte : Dans la Bible chrétienne, nous n’utiliserons que l...
# [80] ✅ Texte traduit ajouté au fichier .txt
# [81] Traduction du texte : 6 Il est quand même étonnant que la France ait ces...
# [81] ✅ Texte traduit ajouté au fichier .txt
# [82] Traduction du texte : 12...
# [82] ✅ Texte traduit ajouté au fichier .txt
# [83] (Paragraphe vide ignoré)
# [84] Traduction du texte : ferons référence qu'aux Evangiles. Ceux-ci raconte...
# [84] ✅ Texte traduit ajouté au fichier .txt
# [85] Traduction du texte : 1. La narration, par des témoins oculaires des évé...
# [85] ✅ Texte traduit ajouté au fichier .txt
# [86] Traduction du texte : 2. Les paroles et les mots prononcés par le Christ...
# [86] ✅ Texte traduit ajouté au fichier .txt
# [87] Traduction du texte : Ce sont les seules paroles du Christ, qui représen...
# [87] ✅ Texte traduit ajouté au fichier .txt
# [88] Traduction du texte : Pourquoi ?...
# [88] ✅ Texte traduit ajouté au fichier .txt
# [89] Traduction du texte : A l’intérieur des évangiles qui racontent la vie s...
# [89] ✅ Texte traduit ajouté au fichier .txt
# [90] Traduction du texte : • La narration, par des témoins oculaires des évén...
# [90] ✅ Texte traduit ajouté au fichier .txt
# [91] Traduction du texte : • Les paroles et les mots prononcés par le Christ ...
# [91] ✅ Texte traduit ajouté au fichier .txt
# [92] Traduction du texte : A l’intérieur de ces évangiles, les paroles du Chr...
# [92] ✅ Texte traduit ajouté au fichier .txt
# [93] Traduction du texte : Eh bien, la seule chose qui nous intéresse et dont...
# [93] ✅ Texte traduit ajouté au fichier .txt
# [94] Traduction du texte : 13...
# [94] ✅ Texte traduit ajouté au fichier .txt
# [95] (Paragraphe vide ignoré)
# [96] Traduction du texte : La chose du monde la plus difficile quand on vit t...
# [96] ✅ Texte traduit ajouté au fichier .txt
# [97] Traduction du texte : Quiconque vit à Paris est toujours amusé devant l’...
# [97] ✅ Texte traduit ajouté au fichier .txt
# [98] Traduction du texte : Il en est de même pour les textes que nous avons t...
# [98] ✅ Texte traduit ajouté au fichier .txt
# [99] Traduction du texte : Bien plus, nous ne savons plus faire la différence...
# [99] ✅ Texte traduit ajouté au fichier .txt
# [100] Traduction du texte : Les paroles du Christ se reconnaissent entre toute...
# [100] ✅ Texte traduit ajouté au fichier .txt
# [101] Traduction du texte : Il y a en elles une musique, une logique, une tend...
# [101] ✅ Texte traduit ajouté au fichier .txt
# [102] Traduction du texte : N’utiliser que ses mots, c’est libérer la pierre p...
# [102] ✅ Texte traduit ajouté au fichier .txt
# [103] Traduction du texte : Ses paroles, en tout, couvrent peut être soixante ...
# [103] ✅ Texte traduit ajouté au fichier .txt
# [104] Traduction du texte : Mais, pour parler très honnêtement, ce que les Pèr...
# [104] ✅ Texte traduit ajouté au fichier .txt
# [105] Traduction du texte : 14...
# [105] ✅ Texte traduit ajouté au fichier .txt
# [106] (Paragraphe vide ignoré)
# [107] Traduction du texte : Car ce livre n’est pas un livre religieux, mais un...
# [107] ✅ Texte traduit ajouté au fichier .txt
# [108] Traduction du texte : Dans son premier livre, basée sur des réalités sci...
# [108] ✅ Texte traduit ajouté au fichier .txt
# [109] Traduction du texte : Rien n’avait été soutenu qui n’ait été prouvé avan...
# [109] ✅ Texte traduit ajouté au fichier .txt
# [110] Traduction du texte : Dans ce second livre, ou par définition même, une ...
# [110] ✅ Texte traduit ajouté au fichier .txt
# [111] Traduction du texte : La logique se prête à la mesure et à l’objectivité...
# [111] ✅ Texte traduit ajouté au fichier .txt
# [112] Traduction du texte : La méthodologie sera donc fort différente....
# [112] ✅ Texte traduit ajouté au fichier .txt
# [113] Traduction du texte : Lorsque nous aurons a dérouler des enchaînements l...
# [113] ✅ Texte traduit ajouté au fichier .txt
# [114] Traduction du texte : Lorsque nous passerons dans le mode " moral ", nou...
# [114] ✅ Texte traduit ajouté au fichier .txt
# [115] Traduction du texte : Nous utiliserons donc deux sortes de procédés dans...
# [115] ✅ Texte traduit ajouté au fichier .txt
# [116] Traduction du texte : 15...
# [116] ✅ Texte traduit ajouté au fichier .txt
# [117] (Paragraphe vide ignoré)
# [118] Traduction du texte : la peine de structurer ses arguments avant, ou pen...
# [118] ✅ Texte traduit ajouté au fichier .txt
# [119] Traduction du texte : • La logique Aristotélicienne : il existe des caus...
# [119] ✅ Texte traduit ajouté au fichier .txt
# [120] Traduction du texte : La seule autorité que nous invoquerons lors de nos...
# [120] ✅ Texte traduit ajouté au fichier .txt
# [121] Traduction du texte : Ce qui est du ressort de la connaissance est diffé...
# [121] ✅ Texte traduit ajouté au fichier .txt
# [122] Traduction du texte : Cela va donc introduire dans le livre une tension ...
# [122] ✅ Texte traduit ajouté au fichier .txt
# [123] Traduction du texte : Cette tension, nous essaierons de la limiter en re...
# [123] ✅ Texte traduit ajouté au fichier .txt
# [124] Traduction du texte : 7 Ou encore plus souvent, après, dans l’escalier, ...
# [124] ✅ Texte traduit ajouté au fichier .txt
# [125] Traduction du texte : 16...
# [125] ✅ Texte traduit ajouté au fichier .txt
# [126] (Paragraphe vide ignoré)
# [127] Traduction du texte : Mais il ne faut pas se faire d’illusions....
# [127] ✅ Texte traduit ajouté au fichier .txt
# [128] Traduction du texte : Ce que le lecteur va lire, c’est ce que l’auteur c...
# [128] ✅ Texte traduit ajouté au fichier .txt
# [129] Traduction du texte : Il se trouve que l’auteur a une nature simple : il...
# [129] ✅ Texte traduit ajouté au fichier .txt
# [130] Traduction du texte : Ce qui rejoint (déjà !) admirablement une parole d...
# [130] ✅ Texte traduit ajouté au fichier .txt
# [131] Traduction du texte : Donc, l’auteur va sûrement faire de fort mauvaises...
# [131] ✅ Texte traduit ajouté au fichier .txt
# [132] Traduction du texte : Mais de ça, hélas, il ne peut être sûr....
# [132] ✅ Texte traduit ajouté au fichier .txt
# [133] Traduction du texte : Ce deuxième livre tiendra donc en fait beaucoup de...
# [133] ✅ Texte traduit ajouté au fichier .txt
# [134] Traduction du texte : La question que nous posons, et à laquelle nous al...
# [134] ✅ Texte traduit ajouté au fichier .txt
# [135] Traduction du texte : 9 Le texte utilisé pour les citations sera celui d...
# [135] ✅ Texte traduit ajouté au fichier .txt
# [136] Traduction du texte : 17...
# [136] ✅ Texte traduit ajouté au fichier .txt
# [137] (Paragraphe vide ignoré)
# [138] Traduction du texte : Si les évangiles sont le fondement même de notre c...
# [138] ✅ Texte traduit ajouté au fichier .txt
# [139] Traduction du texte : Peut être ont-ils été trop lus et commentés par de...
# [139] ✅ Texte traduit ajouté au fichier .txt
# [140] Traduction du texte : Nos commentaires (des Evangiles) seront donc faits...
# [140] ✅ Texte traduit ajouté au fichier .txt
# [141] Traduction du texte : Pour aider à la compréhension du lecteur il nous f...
# [141] ✅ Texte traduit ajouté au fichier .txt
# [142] Traduction du texte : Dans le premier chapitre nous nous attachons à dém...
# [142] ✅ Texte traduit ajouté au fichier .txt
# [143] Traduction du texte : Nous essayons aussi d’expliquer pourquoi le messag...
# [143] ✅ Texte traduit ajouté au fichier .txt
# [144] Traduction du texte : Dans le deuxième chapitre, nous retraçons la genès...
# [144] ✅ Texte traduit ajouté au fichier .txt
# [145] Traduction du texte : 18...
# [145] ✅ Texte traduit ajouté au fichier .txt
# [146] (Paragraphe vide ignoré)
# [147] Traduction du texte : En utilisant nos connaissances historiques et écon...
# [147] ✅ Texte traduit ajouté au fichier .txt
# [148] Traduction du texte : Ces deux chapitres sont donc le cœur même de ce pe...
# [148] ✅ Texte traduit ajouté au fichier .txt
# [149] Traduction du texte : A partir du troisième chapitre, le corps de doctri...
# [149] ✅ Texte traduit ajouté au fichier .txt
# [150] Traduction du texte : 19...
# [150] ✅ Texte traduit ajouté au fichier .txt
# [151] (Paragraphe vide ignoré)
# [152] Traduction du texte : 20...
# [152] ✅ Texte traduit ajouté au fichier .txt
# [153] (Paragraphe vide ignoré)
# [154] Traduction du texte : Chapitre I...
# [154] ✅ Texte traduit ajouté au fichier .txt
# [155] Traduction du texte : Tout commence par un coup de foudre...
# [155] ✅ Texte traduit ajouté au fichier .txt
# [156] Traduction du texte : "Parce que c’était lui, parce que c’était moi…"...
# [156] ✅ Texte traduit ajouté au fichier .txt
# [157] Traduction du texte : Montaigne...
# [157] ✅ Texte traduit ajouté au fichier .txt
# [158] Traduction du texte : Il y a quatre Evangiles....
# [158] ✅ Texte traduit ajouté au fichier .txt
# [159] Traduction du texte : Les premiers, ceux de Marc et Matthieu, ont été éc...
# [159] ✅ Texte traduit ajouté au fichier .txt
# [160] Traduction du texte : L’Evangile selon Saint Marc a sans doute été écrit...
# [160] ✅ Texte traduit ajouté au fichier .txt
# [161] Traduction du texte : Matthieu, collecteur d’impôts pour la douane, fonc...
# [161] ✅ Texte traduit ajouté au fichier .txt
# [162] Traduction du texte : Enfin Jean, l’intellectuel de service, très jeune ...
# [162] ✅ Texte traduit ajouté au fichier .txt
# [163] Traduction du texte : 21...
# [163] ✅ Texte traduit ajouté au fichier .txt
# [164] (Paragraphe vide ignoré)
# [165] Traduction du texte : Il est difficile d’imaginer une plus remarquable c...
# [165] ✅ Texte traduit ajouté au fichier .txt
# [166] Traduction du texte : Pourtant leurs écrits ont changé le monde…...
# [166] ✅ Texte traduit ajouté au fichier .txt
# [167] Traduction du texte : Il s’est donc passé en Palestine, il y a 2000 ans,...
# [167] ✅ Texte traduit ajouté au fichier .txt
# [168] Traduction du texte : Vous avez peut-être vu le film américain, West Sid...
# [168] ✅ Texte traduit ajouté au fichier .txt
# [169] Traduction du texte : Eh bien, ces hommes de Palestine, il y a plus de v...
# [169] ✅ Texte traduit ajouté au fichier .txt
# [170] Traduction du texte : Et Celui qui les voyait, leur a dit : " Viens, et ...
# [170] ✅ Texte traduit ajouté au fichier .txt
# [171] Traduction du texte : C'est en cela que les Evangiles forment une œuvre ...
# [171] ✅ Texte traduit ajouté au fichier .txt
# [172] Traduction du texte : 22...
# [172] ✅ Texte traduit ajouté au fichier .txt
# [173] (Paragraphe vide ignoré)
# [174] Traduction du texte : la surprise immense de quatre témoins devant une p...
# [174] ✅ Texte traduit ajouté au fichier .txt
# [175] Traduction du texte : De l’avoir côtoyée, d’avoir été choisis par elle, ...
# [175] ✅ Texte traduit ajouté au fichier .txt
# [176] Traduction du texte : La puissance de ce Livre, ne s'apparente ni à une ...
# [176] ✅ Texte traduit ajouté au fichier .txt
# [177] Traduction du texte : Le Christ, à notre connaissance, n’a jamais écrit ...
# [177] ✅ Texte traduit ajouté au fichier .txt
# [178] Traduction du texte : Veut-il par là nous indiquer la valeur qu’il attac...
# [178] ✅ Texte traduit ajouté au fichier .txt
# [179] Traduction du texte : Quand les questions se faisaient trop précises, Il...
# [179] ✅ Texte traduit ajouté au fichier .txt
# [180] Traduction du texte : Tu connais les commandements :
# Ne commets point d...
# [180] ✅ Texte traduit ajouté au fichier .txt
# [181] Traduction du texte : Si le questionneur insistait, il répondait toujour...
# [181] ✅ Texte traduit ajouté au fichier .txt
# [182] Traduction du texte : Il n’y a pas de recettes pour être un bon chrétien...
# [182] ✅ Texte traduit ajouté au fichier .txt
# [183] Traduction du texte : 23...
# [183] ✅ Texte traduit ajouté au fichier .txt
# [184] (Paragraphe vide ignoré)
# [185] Traduction du texte : La religion chrétienne n’est en rien un ensemble d...
# [185] ✅ Texte traduit ajouté au fichier .txt
# [186] Traduction du texte : Ce n’est pas la Torah, encore moins le Coran....
# [186] ✅ Texte traduit ajouté au fichier .txt
# [187] Traduction du texte : C’est l’histoire d’une personne qui est venu sur t...
# [187] ✅ Texte traduit ajouté au fichier .txt
# [188] Traduction du texte : L’extraordinaire de cette histoire ? Deux mille an...
# [188] ✅ Texte traduit ajouté au fichier .txt
# [189] Traduction du texte : Siècle après siècle, des hommes, des femmes, des e...
# [189] ✅ Texte traduit ajouté au fichier .txt
# [190] Traduction du texte : Et ce qu’ils suivent, ce n’est pas une idéologie, ...
# [190] ✅ Texte traduit ajouté au fichier .txt
# [191] Traduction du texte : Les Evangiles, et ensuite toute l’histoire des gra...
# [191] ✅ Texte traduit ajouté au fichier .txt
# [192] Traduction du texte : Il faut bien, alors, se rendre à l'évidence d'une ...
# [192] ✅ Texte traduit ajouté au fichier .txt
# [193] Traduction du texte : Chacun des Evangélistes a fait ce qu’il a pu, dans...
# [193] ✅ Texte traduit ajouté au fichier .txt
# [194] Traduction du texte : 24...
# [194] ✅ Texte traduit ajouté au fichier .txt
# [195] (Paragraphe vide ignoré)
# [196] Traduction du texte : Le résultat est surprenant. Au moins les quatre Ev...
# [196] ✅ Texte traduit ajouté au fichier .txt
# [197] Traduction du texte : Si l’on en croit Jésus, Dieu ne s’intéresse qu’à c...
# [197] ✅ Texte traduit ajouté au fichier .txt
# [198] Traduction du texte : Je  suis le chemin, la Vérité et la Vie....
# [198] ✅ Texte traduit ajouté au fichier .txt
# [199] Traduction du texte : Nul ne vient au Père que par Moi....
# [199] ✅ Texte traduit ajouté au fichier .txt
# [200] Traduction du texte : Si vous me connaissiez, vous connaîtriez aussi mon...
# [200] ✅ Texte traduit ajouté au fichier .txt
# [201] Traduction du texte : Je suis le vrai cep et mon père est le vigneron : ...
# [201] ✅ Texte traduit ajouté au fichier .txt
# [202] Traduction du texte : Celui qui demeure en moi et en qui je demeure port...
# [202] ✅ Texte traduit ajouté au fichier .txt
# [203] Traduction du texte : Le message est d'une éloquente simplicité : l’amou...
# [203] ✅ Texte traduit ajouté au fichier .txt
# [204] Traduction du texte : 11 La formule est d’André Frossard dans Dieu exist...
# [204] ✅ Texte traduit ajouté au fichier .txt
# [205] Traduction du texte : 12 Souligné par l’auteur. Cette affirmation de Jés...
# [205] ✅ Texte traduit ajouté au fichier .txt
# [206] Traduction du texte : Comme Socrate, Jésus est mort parce que ses concit...
# [206] ✅ Texte traduit ajouté au fichier .txt
# [207] Traduction du texte : 25...
# [207] ✅ Texte traduit ajouté au fichier .txt
# [208] (Paragraphe vide ignoré)
# [209] Traduction du texte : C’est tout....
# [209] ✅ Texte traduit ajouté au fichier .txt
# [210] Traduction du texte : Il n’y a pas d’amour collectif....
# [210] ✅ Texte traduit ajouté au fichier .txt
# [211] Traduction du texte : Il n’y a pas d’amour de l’humanité, avec un grand ...
# [211] ✅ Texte traduit ajouté au fichier .txt
# [212] Traduction du texte : Il n’y a que l’amour qui va du Christ à un homme o...
# [212] ✅ Texte traduit ajouté au fichier .txt
# [213] Traduction du texte : Un homme qui descendait de Jérusalem à Jéricho tom...
# [213] ✅ Texte traduit ajouté au fichier .txt
# [214] Traduction du texte : Ils le dépouillèrent, le rouèrent de coups et s’en...
# [214] ✅ Texte traduit ajouté au fichier .txt
# [215] Traduction du texte : Par hasard un prêtre descendait par ce chemin. Il ...
# [215] ✅ Texte traduit ajouté au fichier .txt
# [216] Traduction du texte : Il le vit et passa de l'autre côté....
# [216] ✅ Texte traduit ajouté au fichier .txt
# [217] Traduction du texte : Mais un Samaritain qui était en voyage arriva près...
# [217] ✅ Texte traduit ajouté au fichier .txt
# [218] Traduction du texte : Il s'approcha, pansa ses plaies en y versant de l'...
# [218] ✅ Texte traduit ajouté au fichier .txt
# [219] Traduction du texte : Le lendemain, il sortit deux pièces d'argent et le...
# [219] ✅ Texte traduit ajouté au fichier .txt
# [220] Traduction du texte : Il n’existe de responsabilité, d’amour ou de moral...
# [220] ✅ Texte traduit ajouté au fichier .txt
# [221] Traduction du texte : 26...
# [221] ✅ Texte traduit ajouté au fichier .txt
# [222] (Paragraphe vide ignoré)
# [223] Traduction du texte : Je n'ai pas le moindre doute que le prêtre et le l...
# [223] ✅ Texte traduit ajouté au fichier .txt
# [224] Traduction du texte : Ce qui d'ailleurs prenait tout leur temps et les e...
# [224] ✅ Texte traduit ajouté au fichier .txt
# [225] Traduction du texte : Heureusement, pour le pauvre voyageur, le Samarita...
# [225] ✅ Texte traduit ajouté au fichier .txt
# [226] Traduction du texte : Ce que nous dit le Christ, encore et encore, c’est...
# [226] ✅ Texte traduit ajouté au fichier .txt
# [227] Traduction du texte : Il n’y a d’amour qu’individuel.
# Voilà la loi du S...
# [227] ✅ Texte traduit ajouté au fichier .txt
# [228] Traduction du texte : • Il n’y a pas d’amour collectif,
# • Il n’y a pas ...
# [228] ✅ Texte traduit ajouté au fichier .txt
# [229] Traduction du texte : La conséquence logique est effrayante : nous seron...
# [229] ✅ Texte traduit ajouté au fichier .txt
# [230] Traduction du texte : Le "jugement de l’Histoire ", si cher à nos politi...
# [230] ✅ Texte traduit ajouté au fichier .txt
# [231] Traduction du texte : A quoi sert à un homme d’avoir conquis le monde s’...
# [231] ✅ Texte traduit ajouté au fichier .txt
# [232] Traduction du texte : 27...
# [232] ✅ Texte traduit ajouté au fichier .txt
# [233] (Paragraphe vide ignoré)
# [234] Traduction du texte : Et notre responsabilité individuelle sera jugée en...
# [234] ✅ Texte traduit ajouté au fichier .txt
# [235] Traduction du texte : L'injonction tombe comme un couperet :...
# [235] ✅ Texte traduit ajouté au fichier .txt
# [236] Traduction du texte : On exigera beaucoup de celui à qui l’on aura beauc...
# [236] ✅ Texte traduit ajouté au fichier .txt
# [237] Traduction du texte : "Nous sommes des serviteurs inutiles....
# [237] ✅ Texte traduit ajouté au fichier .txt
# [238] Traduction du texte : Nous n’avons fait que ce que nous devions faire"....
# [238] ✅ Texte traduit ajouté au fichier .txt
# [239] Traduction du texte : Phrases terribles, s’il en fût....
# [239] ✅ Texte traduit ajouté au fichier .txt
# [240] Traduction du texte : D’elles sont nées toute la tension créatrice qui a...
# [240] ✅ Texte traduit ajouté au fichier .txt
# [241] Traduction du texte : Il est relativement facile de se dire bon musulman...
# [241] ✅ Texte traduit ajouté au fichier .txt
# [242] Traduction du texte : Or, nul ne peut se dire en conscience, un "bon chr...
# [242] ✅ Texte traduit ajouté au fichier .txt
# [243] Traduction du texte : Les Evangiles ne sont pas un livre, mais une renco...
# [243] ✅ Texte traduit ajouté au fichier .txt
# [244] Traduction du texte : De quoi devenir fou, ou saint… d'ailleurs et assez...
# [244] ✅ Texte traduit ajouté au fichier .txt
# [245] Traduction du texte : 28...
# [245] ✅ Texte traduit ajouté au fichier .txt
# [246] (Paragraphe vide ignoré)
# [247] Traduction du texte : Car quand on aime, on ne peut jamais donner assez ...
# [247] ✅ Texte traduit ajouté au fichier .txt
# [248] Traduction du texte : Celui qui n’a pas tout donné n’a rien donné…...
# [248] ✅ Texte traduit ajouté au fichier .txt
# [249] Traduction du texte : Mais qu’est ce que " tout " ?...
# [249] ✅ Texte traduit ajouté au fichier .txt
# [250] Traduction du texte : A ce stade de notre réflexion, je crois qu'il devi...
# [250] ✅ Texte traduit ajouté au fichier .txt
# [251] Traduction du texte : Toute religion a, me semble-t-il, trois axes de dé...
# [251] ✅ Texte traduit ajouté au fichier .txt
# [252] Traduction du texte : •	la relation verticale à Dieu. C'est le judaïsme....
# [252] ✅ Texte traduit ajouté au fichier .txt
# [253] Traduction du texte : •	la relation intérieure avec soi-même. C'est le 	...
# [253] ✅ Texte traduit ajouté au fichier .txt
# [254] Traduction du texte : •	la relation horizontale avec les autres. C'est l...
# [254] ✅ Texte traduit ajouté au fichier .txt
# [255] Traduction du texte : L’essence de la religion musulmane et de la religi...
# [255] ✅ Texte traduit ajouté au fichier .txt
# [256] Traduction du texte : Il en va tout différemment dans la religion chréti...
# [256] ✅ Texte traduit ajouté au fichier .txt
# [257] Traduction du texte : 13 Les pratiques ont cependant fort différentes, l...
# [257] ✅ Texte traduit ajouté au fichier .txt
# [258] Traduction du texte : 29...
# [258] ✅ Texte traduit ajouté au fichier .txt
# [259] (Paragraphe vide ignoré)
# [260] Traduction du texte : C’est pourquoi, l’une des plus grandes erreurs de ...
# [260] ✅ Texte traduit ajouté au fichier .txt
# [261] Traduction du texte : La religion chrétienne ne repose pas sur un livre,...
# [261] ✅ Texte traduit ajouté au fichier .txt
# [262] Traduction du texte : Mahomet a beaucoup emprunté à la Torah et à l’Anci...
# [262] ✅ Texte traduit ajouté au fichier .txt
# [263] Traduction du texte : L’essence de la religion chrétienne n’est ni de de...
# [263] ✅ Texte traduit ajouté au fichier .txt
# [264] Traduction du texte : Car, nous le savons tous, l’amour ne se conçoit qu...
# [264] ✅ Texte traduit ajouté au fichier .txt
# [265] Traduction du texte : Dieu veut être aimé par chacun d’entre nous, libre...
# [265] ✅ Texte traduit ajouté au fichier .txt
# [266] Traduction du texte : Chacun d’entre nous est libre de ses choix, à tout...
# [266] ✅ Texte traduit ajouté au fichier .txt
# [267] Traduction du texte : L’essence de cette parole, c’est que non seulement...
# [267] ✅ Texte traduit ajouté au fichier .txt
# [268] Traduction du texte : 14 L’Eglise catholique avait perdu de vue cette ré...
# [268] ✅ Texte traduit ajouté au fichier .txt
# [269] Traduction du texte : 30...
# [269] ✅ Texte traduit ajouté au fichier .txt
# [270] (Paragraphe vide ignoré)
# [271] Traduction du texte : nos proches. Ce qui est en rupture totale avec tou...
# [271] ✅ Texte traduit ajouté au fichier .txt
# [272] Traduction du texte : Ne pensez pas que je suis venu apporter la paix su...
# [272] ✅ Texte traduit ajouté au fichier .txt
# [273] Traduction du texte : On songe à Sainte Jeanne de Chantal, marchant sur ...
# [273] ✅ Texte traduit ajouté au fichier .txt
# [274] Traduction du texte : Elle voulait fonder un ordre monastique, ce qu’ell...
# [274] ✅ Texte traduit ajouté au fichier .txt
# [275] Traduction du texte : Le message des Evangiles est un cri d’individualis...
# [275] ✅ Texte traduit ajouté au fichier .txt
# [276] Traduction du texte : Et nos choix sont plus importants, oh combien, que...
# [276] ✅ Texte traduit ajouté au fichier .txt
# [277] Traduction du texte : Comme l’a résumé Jean Paul II dans l’une de ces en...
# [277] ✅ Texte traduit ajouté au fichier .txt
# [278] Traduction du texte : 31...
# [278] ✅ Texte traduit ajouté au fichier .txt
# [279] (Paragraphe vide ignoré)
# [280] Traduction du texte : En conséquence, toute liberté individuelle s’organ...
# [280] ✅ Texte traduit ajouté au fichier .txt
# [281] Traduction du texte : • La possibilité d’exercer son choix qui dépend de...
# [281] ✅ Texte traduit ajouté au fichier .txt
# [282] Traduction du texte : • La volonté de l’exercer, ce qui suppose du carac...
# [282] ✅ Texte traduit ajouté au fichier .txt
# [283] Traduction du texte : • Enfin la capacité morale à juger de ce qui est n...
# [283] ✅ Texte traduit ajouté au fichier .txt
# [284] Traduction du texte : Et puisque nous évoquons pour la première fois le ...
# [284] ✅ Texte traduit ajouté au fichier .txt
# [285] Traduction du texte : Et comme nous l’avons fait pour les évangiles, rev...
# [285] ✅ Texte traduit ajouté au fichier .txt
# [286] Traduction du texte : 15 L’auteur a beaucoup hésité pour savoir s’il dev...
# [286] ✅ Texte traduit ajouté au fichier .txt
# [287] Traduction du texte : 32...
# [287] ✅ Texte traduit ajouté au fichier .txt
# [288] (Paragraphe vide ignoré)
# [289] Traduction du texte : Chapitre II...
# [289] ✅ Texte traduit ajouté au fichier .txt
# [290] Traduction du texte : Le patient socialiste est mort,
# l’électro-encépha...
# [290] ✅ Texte traduit ajouté au fichier .txt
# [291] Traduction du texte : Où l’auteur montre que les débats d’idées souvent ...
# [291] ✅ Texte traduit ajouté au fichier .txt
# [292] Traduction du texte : Car, après tout, et comme le souligne un humoriste...
# [292] ✅ Texte traduit ajouté au fichier .txt
# [293] Traduction du texte : Il n’y a eu que six idées importantes émises depui...
# [293] ✅ Texte traduit ajouté au fichier .txt
# [294] Traduction du texte : Tout est en Dieu (Abraham)
# Tout est dans la Loi (...
# [294] ✅ Texte traduit ajouté au fichier .txt
# [295] Traduction du texte : Et le sujet de ce livre est un peu la confrontatio...
# [295] ✅ Texte traduit ajouté au fichier .txt
# [296] Traduction du texte : La première révolution industrielle, celle qui vit...
# [296] ✅ Texte traduit ajouté au fichier .txt
# [297] Traduction du texte : 33...
# [297] ✅ Texte traduit ajouté au fichier .txt
# [298] (Paragraphe vide ignoré)
# [299] Traduction du texte : nouvelles. La machine à vapeur, puisque c’est d’el...
# [299] ✅ Texte traduit ajouté au fichier .txt
# [300] Traduction du texte : La deuxième contrepartie, c’était la nécessité d’u...
# [300] ✅ Texte traduit ajouté au fichier .txt
# [301] Traduction du texte : Résumons ....
# [301] ✅ Texte traduit ajouté au fichier .txt
# [302] Traduction du texte : La première révolution industrielle concentre au m...
# [302] ✅ Texte traduit ajouté au fichier .txt
# [303] Traduction du texte : 16 Cette différence, elle s’appelle profit (toujou...
# [303] ✅ Texte traduit ajouté au fichier .txt
# [304] Traduction du texte : 34...
# [304] ✅ Texte traduit ajouté au fichier .txt
# [305] (Paragraphe vide ignoré)
# [306] Traduction du texte : leurs intérêts, ces populations très naturellement...
# [306] ✅ Texte traduit ajouté au fichier .txt
# [307] Traduction du texte : On aurait pu imaginer que ces organisations resten...
# [307] ✅ Texte traduit ajouté au fichier .txt
# [308] Traduction du texte : De ce fait, assez rapidement, ces organisations em...
# [308] ✅ Texte traduit ajouté au fichier .txt
# [309] Traduction du texte : Et ce bagage conceptuel, que nous traînons encore ...
# [309] ✅ Texte traduit ajouté au fichier .txt
# [310] Traduction du texte : 17 Comme le disait un Pape : " Tant qu’une hérésie...
# [310] ✅ Texte traduit ajouté au fichier .txt
# [311] Traduction du texte : 35...
# [311] ✅ Texte traduit ajouté au fichier .txt
# [312] (Paragraphe vide ignoré)
# [313] Traduction du texte : d’appeler les économistes " classiques ", en parti...
# [313] ✅ Texte traduit ajouté au fichier .txt
# [314] Traduction du texte : La Valeur : Comme l’ont montre les économistes Aut...
# [314] ✅ Texte traduit ajouté au fichier .txt
# [315] Traduction du texte : La Loi d’airain des salaires annonçait que du fait...
# [315] ✅ Texte traduit ajouté au fichier .txt
# [316] Traduction du texte : La baisse tendancielle de la rentabilité du capita...
# [316] ✅ Texte traduit ajouté au fichier .txt
# [317] Traduction du texte : 36...
# [317] ✅ Texte traduit ajouté au fichier .txt
# [318] (Paragraphe vide ignoré)
# [319] Traduction du texte : amenaient inéluctablement à des concentrations et ...
# [319] ✅ Texte traduit ajouté au fichier .txt
# [320] Traduction du texte : Chez Malthus , ils prirent avec délectation l’idée...
# [320] ✅ Texte traduit ajouté au fichier .txt
# [321] Traduction du texte : Comme on le voit, toute la théorie classique était...
# [321] ✅ Texte traduit ajouté au fichier .txt
# [322] Traduction du texte : Marx et Lénine sautèrent avec enthousiasme sur ces...
# [322] ✅ Texte traduit ajouté au fichier .txt
# [323] Traduction du texte : De la présence aux mêmes endroits de masses immens...
# [323] ✅ Texte traduit ajouté au fichier .txt
# [324] Traduction du texte : 20 Bien des mouvements écologiques empruntent tout...
# [324] ✅ Texte traduit ajouté au fichier .txt
# [325] Traduction du texte : 37...
# [325] ✅ Texte traduit ajouté au fichier .txt
# [326] (Paragraphe vide ignoré)
# [327] Traduction du texte : classe est représentée par un vocable, d’un coté l...
# [327] ✅ Texte traduit ajouté au fichier .txt
# [328] Traduction du texte : Et ce sera le " grand soir ", la fin de l’histoire...
# [328] ✅ Texte traduit ajouté au fichier .txt
# [329] Traduction du texte : Lénine, en déduisit fort logiquement que dans ces ...
# [329] ✅ Texte traduit ajouté au fichier .txt
# [330] Traduction du texte : Ces grandes et profondes idées se rejoignirent dan...
# [330] ✅ Texte traduit ajouté au fichier .txt
# [331] Traduction du texte : 38...
# [331] ✅ Texte traduit ajouté au fichier .txt
# [332] (Paragraphe vide ignoré)
# [333] Traduction du texte : gare, sans nous prévenir, on nous change la nature...
# [333] ✅ Texte traduit ajouté au fichier .txt
# [334] Traduction du texte : C’est maintenant cette répartition égalitaire qui ...
# [334] ✅ Texte traduit ajouté au fichier .txt
# [335] Traduction du texte : Le lecteur aura immédiatement remarqué le saut log...
# [335] ✅ Texte traduit ajouté au fichier .txt
# [336] Traduction du texte : C’est bien entendu dans ce saut d’une morale indiv...
# [336] ✅ Texte traduit ajouté au fichier .txt
# [337] Traduction du texte : Il faut faire ici deux remarques ;
# • Les racines ...
# [337] ✅ Texte traduit ajouté au fichier .txt
# [338] Traduction du texte : 21 Autrefois, dans l’enfance de l’auteur, dans l’h...
# [338] ✅ Texte traduit ajouté au fichier .txt
# [339] Traduction du texte : 22 La NEP consacra l’abandon de la politique écono...
# [339] ✅ Texte traduit ajouté au fichier .txt
# [340] Traduction du texte : 39...
# [340] ✅ Texte traduit ajouté au fichier .txt
# [341] (Paragraphe vide ignoré)
# [342] Traduction du texte : Quand nous démontrerons dans le cours du texte que...
# [342] ✅ Texte traduit ajouté au fichier .txt
# [343] Traduction du texte : Dans le fond, nos socialistes regrettent souvent d...
# [343] ✅ Texte traduit ajouté au fichier .txt
# [344] Traduction du texte : Mais ils ont toujours respecté la pureté de l’idéa...
# [344] ✅ Texte traduit ajouté au fichier .txt
# [345] Traduction du texte : Quand ils songent à toutes les saletés que le capi...
# [345] ✅ Texte traduit ajouté au fichier .txt
# [346] Traduction du texte : 23 Nos intellectuels, en particulier en France, ne...
# [346] ✅ Texte traduit ajouté au fichier .txt
# [347] Traduction du texte : 40...
# [347] ✅ Texte traduit ajouté au fichier .txt
# [348] (Paragraphe vide ignoré)
# [349] Traduction du texte : Il nous faut maintenant expliquer pourquoi....
# [349] ✅ Texte traduit ajouté au fichier .txt
# [350] Traduction du texte : Ils avaient oublié tout simplement que l’homme, qu...
# [350] ✅ Texte traduit ajouté au fichier .txt
# [351] Traduction du texte : Alfred Sauvy  à ce propos racontait une charmante ...
# [351] ✅ Texte traduit ajouté au fichier .txt
# [352] Traduction du texte : Ce a quoi Alfred Sauvy avait répondu :...
# [352] ✅ Texte traduit ajouté au fichier .txt
# [353] Traduction du texte : " Monsieur le Ministre, imaginez s’ils avaient des...
# [353] ✅ Texte traduit ajouté au fichier .txt
# [354] Traduction du texte : En termes clairs, les socialistes n’ont jamais int...
# [354] ✅ Texte traduit ajouté au fichier .txt
# [355] Traduction du texte : Ils n’ont vu arriver :...
# [355] ✅ Texte traduit ajouté au fichier .txt
# [356] Traduction du texte : 24 A Sauvy, économiste, démographe, sociologue l’u...
# [356] ✅ Texte traduit ajouté au fichier .txt
# [357] Traduction du texte : 41...
# [357] ✅ Texte traduit ajouté au fichier .txt
# [358] (Paragraphe vide ignoré)
# [359] Traduction du texte : • Ni la révolution énergétique et le passage du ch...
# [359] ✅ Texte traduit ajouté au fichier .txt
# [360] Traduction du texte : • Ni les différentes révolutions dans les transpor...
# [360] ✅ Texte traduit ajouté au fichier .txt
# [361] Traduction du texte : • Ni les progrès de la pharmacie ou de la médecine...
# [361] ✅ Texte traduit ajouté au fichier .txt
# [362] Traduction du texte : • Ni la révolution de l’information (ordinateur, t...
# [362] ✅ Texte traduit ajouté au fichier .txt
# [363] Traduction du texte : Eux les révolutionnaires professionnels, les défen...
# [363] ✅ Texte traduit ajouté au fichier .txt
# [364] Traduction du texte : 25 Pas grand chose à se mettre sous la dent dans l...
# [364] ✅ Texte traduit ajouté au fichier .txt
# [365] Traduction du texte : 42...
# [365] ✅ Texte traduit ajouté au fichier .txt
# [366] (Paragraphe vide ignoré)
# [367] Traduction du texte : ou de ses satellites en quarante ans quand ils éta...
# [367] ✅ Texte traduit ajouté au fichier .txt
# [368] Traduction du texte : La première Révolution Industrielle avait accrue d...
# [368] ✅ Texte traduit ajouté au fichier .txt
# [369] Traduction du texte : Quelque part, la liberté individuelle avait (peut ...
# [369] ✅ Texte traduit ajouté au fichier .txt
# [370] Traduction du texte : La deuxième Révolution Industrielle, celle que nou...
# [370] ✅ Texte traduit ajouté au fichier .txt
# [371] Traduction du texte : Or, comme le disait déjà Jean Bodin au seizième si...
# [371] ✅ Texte traduit ajouté au fichier .txt
# [372] Traduction du texte : Chaque individu dans le monde d’aujourd’hui a accè...
# [372] ✅ Texte traduit ajouté au fichier .txt
# [373] Traduction du texte : 26 Nous disons peut être parce qu’après tout la li...
# [373] ✅ Texte traduit ajouté au fichier .txt
# [374] Traduction du texte : 43...
# [374] ✅ Texte traduit ajouté au fichier .txt
# [375] (Paragraphe vide ignoré)
# [376] Traduction du texte : Le magistère moral que nos esprits socialistes étr...
# [376] ✅ Texte traduit ajouté au fichier .txt
# [377] Traduction du texte : FINI....
# [377] ✅ Texte traduit ajouté au fichier .txt
# [378] Traduction du texte : La tyrannie des soi-disant intellectuels sur ce qu...
# [378] ✅ Texte traduit ajouté au fichier .txt
# [379] Traduction du texte : La valeur du capital humain est en train de faire ...
# [379] ✅ Texte traduit ajouté au fichier .txt
# [380] Traduction du texte : Or l’expression " capital humain " est pour eux in...
# [380] ✅ Texte traduit ajouté au fichier .txt
# [381] Traduction du texte : Ce qui laisse nos socialistes, qui en sont restes ...
# [381] ✅ Texte traduit ajouté au fichier .txt
# [382] Traduction du texte : 27 L’auteur s’excuse de la redondance, mais ce qui...
# [382] ✅ Texte traduit ajouté au fichier .txt
# [383] Traduction du texte : 44...
# [383] ✅ Texte traduit ajouté au fichier .txt
# [384] (Paragraphe vide ignoré)
# [385] Traduction du texte : Car ils n’ont plus aucune explication à fournir su...
# [385] ✅ Texte traduit ajouté au fichier .txt
# [386] Traduction du texte : • Ni la valeur travail,
# 	• ni la théorie de la pl...
# [386] ✅ Texte traduit ajouté au fichier .txt
# [387] Traduction du texte : Que le lecteur, lors d’une discussion avec l’un de...
# [387] ✅ Texte traduit ajouté au fichier .txt
# [388] Traduction du texte : Et qu’il s’amuse du spectacle....
# [388] ✅ Texte traduit ajouté au fichier .txt
# [389] Traduction du texte : Tout cela leur pose un léger problème du point de ...
# [389] ✅ Texte traduit ajouté au fichier .txt
# [390] Traduction du texte : 29 La réponse est simple: les entrepreneurs et uni...
# [390] ✅ Texte traduit ajouté au fichier .txt
# [391] Traduction du texte : 45...
# [391] ✅ Texte traduit ajouté au fichier .txt
# [392] (Paragraphe vide ignoré)
# [393] Traduction du texte : Ces éminentes personnalités justifiaient leur préé...
# [393] ✅ Texte traduit ajouté au fichier .txt
# [394] Traduction du texte : Vont-ils demander pardon à ceux qu’ils ont trompé ...
# [394] ✅ Texte traduit ajouté au fichier .txt
# [395] Traduction du texte : Point du tout, ils sont sur les estrades et les tr...
# [395] ✅ Texte traduit ajouté au fichier .txt
# [396] Traduction du texte : Et leur argumentaire a très brutalement mais très ...
# [396] ✅ Texte traduit ajouté au fichier .txt
# [397] Traduction du texte : Quand l’auteur faisait ses études dans les années ...
# [397] ✅ Texte traduit ajouté au fichier .txt
# [398] Traduction du texte : 46...
# [398] ✅ Texte traduit ajouté au fichier .txt
# [399] (Paragraphe vide ignoré)
# [400] Traduction du texte : Pendant cent cinquante ans, il a fallu mener un co...
# [400] ✅ Texte traduit ajouté au fichier .txt
# [401] Traduction du texte : " Nous devons gouverner parce que nous savons disc...
# [401] ✅ Texte traduit ajouté au fichier .txt
# [402] Traduction du texte : Et avec leur bonne foi habituelle, ils essaient de...
# [402] ✅ Texte traduit ajouté au fichier .txt
# [403] Traduction du texte : Ayant échoué sur le coté Grec, ils se rabattent su...
# [403] ✅ Texte traduit ajouté au fichier .txt
# [404] Traduction du texte : 31 C’est ce que l’on peut appeler la morale Wester...
# [404] ✅ Texte traduit ajouté au fichier .txt
# [405] Traduction du texte : 47...
# [405] ✅ Texte traduit ajouté au fichier .txt
# [406] (Paragraphe vide ignoré)
# [407] Traduction du texte : Ils prétendent que ce qu’ils disent est l’essence ...
# [407] ✅ Texte traduit ajouté au fichier .txt
# [408] Traduction du texte : Il faut se souvenir cependant qu’il y a peu, leur ...
# [408] ✅ Texte traduit ajouté au fichier .txt
# [409] Traduction du texte : Dépouillé de la blouse blanche du savant, nos pens...
# [409] ✅ Texte traduit ajouté au fichier .txt
# [410] Traduction du texte : Et ce message, à notre grande stupéfaction est a n...
# [410] ✅ Texte traduit ajouté au fichier .txt
# [411] Traduction du texte : 48...
# [411] ✅ Texte traduit ajouté au fichier .txt
# [412] (Paragraphe vide ignoré)
# [413] Traduction du texte : événements  inattendus  (par eux) ne les forcent à...
# [413] ✅ Texte traduit ajouté au fichier .txt
# [414] Traduction du texte : Or une lecture attentive du texte montre sans ambi...
# [414] ✅ Texte traduit ajouté au fichier .txt
# [415] Traduction du texte : S’appuyer sur une murale soit disant Chrétienne po...
# [415] ✅ Texte traduit ajouté au fichier .txt
# [416] Traduction du texte : Il suffit de relire les évangiles la plume a la ma...
# [416] ✅ Texte traduit ajouté au fichier .txt
# [417] Traduction du texte : 32 L’ancien premier ministre Britannique MacMillan...
# [417] ✅ Texte traduit ajouté au fichier .txt
# [418] Traduction du texte : 33 Von Mises et Hayek avaient montre de façon logi...
# [418] ✅ Texte traduit ajouté au fichier .txt
# [419] Traduction du texte : 49...
# [419] ✅ Texte traduit ajouté au fichier .txt
# [420] (Paragraphe vide ignoré)
# [421] Traduction du texte : 50...
# [421] ✅ Texte traduit ajouté au fichier .txt
# [422] (Paragraphe vide ignoré)
# [423] Traduction du texte : Chapitre III...
# [423] ✅ Texte traduit ajouté au fichier .txt
# [424] Traduction du texte : Le patient socialiste est mort,
# l’électro-encépha...
# [424] ✅ Texte traduit ajouté au fichier .txt
# [425] Traduction du texte : "Gouverner un royaume, c’est s’assurer que l’on se...
# [425] ✅ Texte traduit ajouté au fichier .txt
# [426] Traduction du texte : Cardinal de Richelieu...
# [426] ✅ Texte traduit ajouté au fichier .txt
# [427] Traduction du texte : Le Diable ayant emmené Jésus lui fit voir en un in...
# [427] ✅ Texte traduit ajouté au fichier .txt
# [428] Traduction du texte : "Je te donnerai toute cette puissance et la gloire...
# [428] ✅ Texte traduit ajouté au fichier .txt
# [429] Traduction du texte : Si donc tu te prosternes devant moi, elles
# t’appa...
# [429] ✅ Texte traduit ajouté au fichier .txt
# [430] Traduction du texte : Jésus lui répondit :...
# [430] ✅ Texte traduit ajouté au fichier .txt
# [431] Traduction du texte : "Il est écrit : tu adoreras le Seigneur ton Dieu, ...
# [431] ✅ Texte traduit ajouté au fichier .txt
# [432] Traduction du texte : Il faut admirer, ici, l’altruisme de ceux qui nous...
# [432] ✅ Texte traduit ajouté au fichier .txt
# [433] Traduction du texte : 51...
# [433] ✅ Texte traduit ajouté au fichier .txt
# [434] (Paragraphe vide ignoré)
# [435] Traduction du texte : Il y a quelques solides condamnations dans les Eva...
# [435] ✅ Texte traduit ajouté au fichier .txt
# [436] Traduction du texte : Très curieusement, l’une de celles dont on parle l...
# [436] ✅ Texte traduit ajouté au fichier .txt
# [437] Traduction du texte : Dès le début de son Evangile, Saint Luc nous dit d...
# [437] ✅ Texte traduit ajouté au fichier .txt
# [438] Traduction du texte : • que Lucifer les donne ensuite à qui il veut....
# [438] ✅ Texte traduit ajouté au fichier .txt
# [439] Traduction du texte : Si on raisonne a contrario, est-on autorisé à dire...
# [439] ✅ Texte traduit ajouté au fichier .txt
# [440] Traduction du texte : Intéressante idée et qui expliquerait bien des cho...
# [440] ✅ Texte traduit ajouté au fichier .txt
# [441] Traduction du texte : Allons plus loin....
# [441] ✅ Texte traduit ajouté au fichier .txt
# [442] Traduction du texte : Tout le monde, en cette période où, en France, on ...
# [442] ✅ Texte traduit ajouté au fichier .txt
# [443] Traduction du texte : 34 En France. Quiconque vit en Grande-Bretagne ou ...
# [443] ✅ Texte traduit ajouté au fichier .txt
# [444] Traduction du texte : 52...
# [444] ✅ Texte traduit ajouté au fichier .txt
# [445] (Paragraphe vide ignoré)
# [446] Traduction du texte : Des personnes mal intentionnées veulent tendre un ...
# [446] ✅ Texte traduit ajouté au fichier .txt
# [447] Traduction du texte : Maître, nous savons que tu parles et enseignes com...
# [447] ✅ Texte traduit ajouté au fichier .txt
# [448] Traduction du texte : Mais Jésus ayant démêlé leur fourberie leur dit : ...
# [448] ✅ Texte traduit ajouté au fichier .txt
# [449] Traduction du texte : De qui porte-t-il l’effigie et la légende ? "...
# [449] ✅ Texte traduit ajouté au fichier .txt
# ...
# [1233] Traduction du texte : Quelles erreurs a-t-Il commises ? Abraham et Moïse...
# [1233] ✅ Texte traduit ajouté au fichier .txt
# [1234] Traduction du texte : 2. Pour un futur indéterminé.
# 3. Sans en avoir re...
# [1234] ✅ Texte traduit ajouté au fichier .txt
# [1235] Traduction du texte : Ils ont promis, juré que les Israélites feraient c...
# [1235] ✅ Texte traduit ajouté au fichier .txt
# [1236] Traduction du texte : 60 En fait en anglais, on appelle ces contrats non...
# [1236] ✅ Texte traduit ajouté au fichier .txt
# [1237] Traduction du texte : 148...
# [1237] ✅ Texte traduit ajouté au fichier .txt
# [1238] (Paragraphe vide ignoré)
# [1239] Traduction du texte : la partie adverse va être capable de respecter sa ...
# [1239] ✅ Texte traduit ajouté au fichier .txt
# [1240] Traduction du texte : De fait, ça n’a pas très bien marché....
# [1240] ✅ Texte traduit ajouté au fichier .txt
# [1241] Traduction du texte : Une partie du peuple juif a respecté et respecte t...
# [1241] ✅ Texte traduit ajouté au fichier .txt
# [1242] Traduction du texte : Mais les riches et les puissants ont eu bien du ma...
# [1242] ✅ Texte traduit ajouté au fichier .txt
# [1243] Traduction du texte : Devant ces manquements répétés, le Seigneur envoie...
# [1243] ✅ Texte traduit ajouté au fichier .txt
# [1244] Traduction du texte : Le peuple les jette dans des citernes – vides! –, ...
# [1244] ✅ Texte traduit ajouté au fichier .txt
# [1245] Traduction du texte : A ce point une question surgit : pourquoi les Juif...
# [1245] ✅ Texte traduit ajouté au fichier .txt
# [1246] Traduction du texte : 149...
# [1246] ✅ Texte traduit ajouté au fichier .txt
# [1247] (Paragraphe vide ignoré)
# [1248] Traduction du texte : jamais aussi bien qu’IL l’espérait ?  Parce que ce...
# [1248] ✅ Texte traduit ajouté au fichier .txt
# [1249] Traduction du texte : Une fois de plus, en lisant les Evangiles nous ne ...
# [1249] ✅ Texte traduit ajouté au fichier .txt
# [1250] Traduction du texte : Je peux consentir à limiter ma liberté....
# [1250] ✅ Texte traduit ajouté au fichier .txt
# [1251] Traduction du texte : Je ne peux pas accepter que quelqu’un d’autre que ...
# [1251] ✅ Texte traduit ajouté au fichier .txt
# [1252] Traduction du texte : Voilà le fond du message de Jésus....
# [1252] ✅ Texte traduit ajouté au fichier .txt
# [1253] Traduction du texte : Sans vouloir insister, contentons-nous de remarque...
# [1253] ✅ Texte traduit ajouté au fichier .txt
# [1254] Traduction du texte : 61 Ce qui étonne dans la Bible, c’est cette impres...
# [1254] ✅ Texte traduit ajouté au fichier .txt
# [1255] Traduction du texte : 150...
# [1255] ✅ Texte traduit ajouté au fichier .txt
# [1256] (Paragraphe vide ignoré)
# [1257] Traduction du texte : soi-disant gouvernements de droite  impliquent, d'...
# [1257] ✅ Texte traduit ajouté au fichier .txt
# [1258] Traduction du texte : Ainsi toutes les conventions collectives sont orga...
# [1258] ✅ Texte traduit ajouté au fichier .txt
# [1259] Traduction du texte : Or il se trouve que dans le monde moderne, les exc...
# [1259] ✅ Texte traduit ajouté au fichier .txt
# [1260] Traduction du texte : Certains se souviennent peut-être d'une gravure qu...
# [1260] ✅ Texte traduit ajouté au fichier .txt
# [1261] Traduction du texte : 62 Reconnaissons- le : celui qui découvre la moind...
# [1261] ✅ Texte traduit ajouté au fichier .txt
# [1262] Traduction du texte : 63 Dans les années Mitterrand, la classe politique...
# [1262] ✅ Texte traduit ajouté au fichier .txt
# [1263] Traduction du texte : 151...
# [1263] ✅ Texte traduit ajouté au fichier .txt
# [1264] (Paragraphe vide ignoré)
# [1265] Traduction du texte : A quand une nouvelle Nuit du 4 août  ?...
# [1265] ✅ Texte traduit ajouté au fichier .txt
# [1266] Traduction du texte : L’exemple archétypal du contrat signé sur le Sinaï...
# [1266] ✅ Texte traduit ajouté au fichier .txt
# [1267] Traduction du texte : Nul n’a envie que le chirurgien qui va l’opérer mu...
# [1267] ✅ Texte traduit ajouté au fichier .txt
# [1268] Traduction du texte : Aujourd’hui, quand bien même on voudrait embaucher...
# [1268] ✅ Texte traduit ajouté au fichier .txt
# [1269] Traduction du texte : 64 Pendant la Nuit du 4 août 1789, la noblesse fra...
# [1269] ✅ Texte traduit ajouté au fichier .txt
# [1270] Traduction du texte : 65 Ce qui n’est pas vrai du tout. Dès que Moise es...
# [1270] ✅ Texte traduit ajouté au fichier .txt
# [1271] Traduction du texte : 152...
# [1271] ✅ Texte traduit ajouté au fichier .txt
# [1272] (Paragraphe vide ignoré)
# [1273] Traduction du texte : des médecins ou des infirmiers, on ne le pourrait ...
# [1273] ✅ Texte traduit ajouté au fichier .txt
# [1274] Traduction du texte : Si l’Union Soviétique a sauté parce que son systèm...
# [1274] ✅ Texte traduit ajouté au fichier .txt
# [1275] Traduction du texte : Or les valeurs et les principes de fonctionnement ...
# [1275] ✅ Texte traduit ajouté au fichier .txt
# [1276] Traduction du texte : Le plus drôle, si on veut : c’est qu'il s'agit du ...
# [1276] ✅ Texte traduit ajouté au fichier .txt
# [1277] Traduction du texte : 153...
# [1277] ✅ Texte traduit ajouté au fichier .txt
# [1278] (Paragraphe vide ignoré)
# [1279] Traduction du texte : clausus pour les études, le budget des hôpitaux et...
# [1279] ✅ Texte traduit ajouté au fichier .txt
# [1280] Traduction du texte : Bref l’Ancien Testament nous démontre que les négo...
# [1280] ✅ Texte traduit ajouté au fichier .txt
# [1281] Traduction du texte : Et voilà comment "certains sont plus égaux que d’a...
# [1281] ✅ Texte traduit ajouté au fichier .txt
# [1282] Traduction du texte : Revenons à Dieu. Au bout d’un certain temps, Lui q...
# [1282] ✅ Texte traduit ajouté au fichier .txt
# [1283] Traduction du texte : Il se dit qu’il lui fallait retourner à la table d...
# [1283] ✅ Texte traduit ajouté au fichier .txt
# [1284] Traduction du texte : Et là, tout change....
# [1284] ✅ Texte traduit ajouté au fichier .txt
# [1285] Traduction du texte : Jésus a compris. Comme nous l’avons déjà expliqué,...
# [1285] ✅ Texte traduit ajouté au fichier .txt
# [1286] Traduction du texte : Fini la massification, ou l’appartenance forcée à ...
# [1286] ✅ Texte traduit ajouté au fichier .txt
# [1287] Traduction du texte : 154...
# [1287] ✅ Texte traduit ajouté au fichier .txt
# [1288] (Paragraphe vide ignoré)
# [1289] Traduction du texte : favoritisme, la corruption, les préséances. On com...
# [1289] ✅ Texte traduit ajouté au fichier .txt
# [1290] Traduction du texte : La notion d’individu est centrale et consubstantie...
# [1290] ✅ Texte traduit ajouté au fichier .txt
# [1291] Traduction du texte : Cette notion trouve sa source originelle dans les ...
# [1291] ✅ Texte traduit ajouté au fichier .txt
# [1292] Traduction du texte : Dans cet esprit, ceux qui ne voient que l’étatisme...
# [1292] ✅ Texte traduit ajouté au fichier .txt
# [1293] Traduction du texte : 66 Même les plus grands esprits peuvent se tromper...
# [1293] ✅ Texte traduit ajouté au fichier .txt
# [1294] Traduction du texte : 155...
# [1294] ✅ Texte traduit ajouté au fichier .txt
# [1295] (Paragraphe vide ignoré)
# [1296] Traduction du texte : A contrario, je me répète, le message des Evangile...
# [1296] ✅ Texte traduit ajouté au fichier .txt
# [1297] Traduction du texte : Quels qu'aient été ses erreurs et même ses crimes,...
# [1297] ✅ Texte traduit ajouté au fichier .txt
# [1298] Traduction du texte : 156...
# [1298] ✅ Texte traduit ajouté au fichier .txt
# [1299] (Paragraphe vide ignoré)
# [1300] Traduction du texte : Conclusion...
# [1300] ✅ Texte traduit ajouté au fichier .txt
# [1301] Traduction du texte : Quand un rocher change le cours d'un fleuve...
# [1301] ✅ Texte traduit ajouté au fichier .txt
# [1302] Traduction du texte : "Le Pape ? Combien de divisions ?"...
# [1302] ✅ Texte traduit ajouté au fichier .txt
# [1303] Traduction du texte : Joseph Staline...
# [1303] ✅ Texte traduit ajouté au fichier .txt
# [1304] Traduction du texte : Churchill disait : "Si vous devez faire un discour...
# [1304] ✅ Texte traduit ajouté au fichier .txt
# [1305] Traduction du texte : On pourrait, à l'évidence, poursuivre et creuser p...
# [1305] ✅ Texte traduit ajouté au fichier .txt
# [1306] Traduction du texte : Au fond, dans les Evangiles, il y a deux bonnes no...
# [1306] ✅ Texte traduit ajouté au fichier .txt
# [1307] Traduction du texte : • La première, à laquelle on peut ne pas croire, e...
# [1307] ✅ Texte traduit ajouté au fichier .txt
# [1308] Traduction du texte : • La seconde : chacun d’entre nous est totalement ...
# [1308] ✅ Texte traduit ajouté au fichier .txt
# [1309] Traduction du texte : Cette extraordinaire intuition du Christ a été con...
# [1309] ✅ Texte traduit ajouté au fichier .txt
# [1310] Traduction du texte : Si je suis unique, mon destin n’appartient qu’à mo...
# [1310] ✅ Texte traduit ajouté au fichier .txt
# [1311] Traduction du texte : 157...
# [1311] ✅ Texte traduit ajouté au fichier .txt
# [1312] (Paragraphe vide ignoré)
# [1313] Traduction du texte : Il ne peut donc y avoir de solutions collectives a...
# [1313] ✅ Texte traduit ajouté au fichier .txt
# [1314] Traduction du texte : Chaque société humaine est continuellement confron...
# [1314] ✅ Texte traduit ajouté au fichier .txt
# [1315] Traduction du texte : Or nos sociétés vont devoir répondre dans les anné...
# [1315] ✅ Texte traduit ajouté au fichier .txt
# [1316] Traduction du texte : Que faire ? Il va falloir extirper du corps de l’E...
# [1316] ✅ Texte traduit ajouté au fichier .txt
# [1317] Traduction du texte : 158...
# [1317] ✅ Texte traduit ajouté au fichier .txt
# [1318] (Paragraphe vide ignoré)
# [1319] Traduction du texte : faisant l’économie d’une révolution consécutive à ...
# [1319] ✅ Texte traduit ajouté au fichier .txt
# [1320] Traduction du texte : L'analyse des enchaînements qui ont amené à la lib...
# [1320] ✅ Texte traduit ajouté au fichier .txt
# [1321] Traduction du texte : Il y a, je crois devoir le dire avec force, une ma...
# [1321] ✅ Texte traduit ajouté au fichier .txt
# [1322] Traduction du texte : Mais, les dix Commandements, c’est la morale juive...
# [1322] ✅ Texte traduit ajouté au fichier .txt
# [1323] Traduction du texte : Il y a, en effet, une morale juive et une pratique...
# [1323] ✅ Texte traduit ajouté au fichier .txt
# [1324] Traduction du texte : Etre chrétien, c'est exercer sa liberté individuel...
# [1324] ✅ Texte traduit ajouté au fichier .txt
# [1325] Traduction du texte : 159...
# [1325] ✅ Texte traduit ajouté au fichier .txt
# [1326] (Paragraphe vide ignoré)
# [1327] Traduction du texte : ordre indigne ou déshonorant peut devenir un acte ...
# [1327] ✅ Texte traduit ajouté au fichier .txt
# [1328] Traduction du texte : "Heureux serez vous si vous êtes emprisonné ou tué...
# [1328] ✅ Texte traduit ajouté au fichier .txt
# [1329] Traduction du texte : Soljenitsyne, dans le Chêne et le Veau, a expliqué...
# [1329] ✅ Texte traduit ajouté au fichier .txt
# [1330] Traduction du texte : Le grand fleuve était l’avancée irrésistible du so...
# [1330] ✅ Texte traduit ajouté au fichier .txt
# [1331] Traduction du texte : 67 Mon père commandait des harkis en Algérie. Il r...
# [1331] ✅ Texte traduit ajouté au fichier .txt
# [1332] Traduction du texte : 160...
# [1332] ✅ Texte traduit ajouté au fichier .txt
# [1333] (Paragraphe vide ignoré)
# [1334] Traduction du texte : Peu de temps après, et à la stupéfaction générale ...
# [1334] ✅ Texte traduit ajouté au fichier .txt
# [1335] Traduction du texte : Puis en Pologne, la création d’un syndicat chrétie...
# [1335] ✅ Texte traduit ajouté au fichier .txt
# [1336] Traduction du texte : Le communisme a souffert d'une défaite morale irré...
# [1336] ✅ Texte traduit ajouté au fichier .txt
# [1337] Traduction du texte : On est condamné à ne rien comprendre de ce qui s’e...
# [1337] ✅ Texte traduit ajouté au fichier .txt
# [1338] Traduction du texte : Pour que s'effondre le monstre soviétique, il a su...
# [1338] ✅ Texte traduit ajouté au fichier .txt
# [1339] Traduction du texte : 68 Soljenitsyne, à l’annonce de l’élection du Pape...
# [1339] ✅ Texte traduit ajouté au fichier .txt
# [1340] Traduction du texte : 161...
# [1340] ✅ Texte traduit ajouté au fichier .txt
# [1341] (Paragraphe vide ignoré)
# [1342] Traduction du texte : doivent le reprendre sans se lasser. Loin d’être u...
# [1342] ✅ Texte traduit ajouté au fichier .txt
# [1343] Traduction du texte : La solution nous a été indiquée par Soljenitsyne, ...
# [1343] ✅ Texte traduit ajouté au fichier .txt
# [1344] Traduction du texte : • Chaque fois qu'il a pu aller jusqu'au bout de sa...
# [1344] ✅ Texte traduit ajouté au fichier .txt
# [1345] Traduction du texte : 162...
# [1345] ✅ Texte traduit ajouté au fichier .txt
# [1346] (Paragraphe vide ignoré)
# [1347] Traduction du texte : socialisme s’attache d’abord à liquider les Chréti...
# [1347] ✅ Texte traduit ajouté au fichier .txt
# [1348] Traduction du texte : • Comme le montre son histoire le socialisme est s...
# [1348] ✅ Texte traduit ajouté au fichier .txt
# [1349] Traduction du texte : • Toute l’histoire du XXème siècle a prouvé que le...
# [1349] ✅ Texte traduit ajouté au fichier .txt
# [1350] Traduction du texte : 69 Et bien entendu, ils ont essaye de liquider le ...
# [1350] ✅ Texte traduit ajouté au fichier .txt
# [1351] Traduction du texte : 70 Pour ceux qui ont la mémoire longue, on se souv...
# [1351] ✅ Texte traduit ajouté au fichier .txt
# [1352] Traduction du texte : 163...
# [1352] ✅ Texte traduit ajouté au fichier .txt
# [1353] (Paragraphe vide ignoré)
# [1354] Traduction du texte : Cette dérive, si souvent criminelle du socialisme,...
# [1354] ✅ Texte traduit ajouté au fichier .txt
# [1355] Traduction du texte : • La liberté civique c’est de pouvoir faire élever...
# [1355] ✅ Texte traduit ajouté au fichier .txt
# [1356] Traduction du texte : Il n’existe aucune raison logique pour dire que la...
# [1356] ✅ Texte traduit ajouté au fichier .txt
# [1357] Traduction du texte : 164...
# [1357] ✅ Texte traduit ajouté au fichier .txt
# [1358] (Paragraphe vide ignoré)
# [1359] Traduction du texte : Tout l’effort du libéralisme a été de protéger les...
# [1359] ✅ Texte traduit ajouté au fichier .txt
# [1360] Traduction du texte : Si la France aujourd'hui, gouvernée depuis quarant...
# [1360] ✅ Texte traduit ajouté au fichier .txt
# [1361] Traduction du texte : Or il faut que les chrétiens français se ressaisis...
# [1361] ✅ Texte traduit ajouté au fichier .txt
# [1362] Traduction du texte : Il faut que chaque chrétien reprenne pour lui-même...
# [1362] ✅ Texte traduit ajouté au fichier .txt
# [1363] Traduction du texte : Lorsqu'une majorité de catholiques français sera c...
# [1363] ✅ Texte traduit ajouté au fichier .txt
# [1364] Traduction du texte : 165...
# [1364] ✅ Texte traduit ajouté au fichier .txt
# [1365] (Paragraphe vide ignoré)
# [1366] Traduction du texte : Il faut retourner à nos racines. Comme j'ai essayé...
# [1366] ✅ Texte traduit ajouté au fichier .txt
# [1367] Traduction du texte : D'où ce petit livre, fragile bouteille jetée à la ...
# [1367] ✅ Texte traduit ajouté au fichier .txt
# [1368] Traduction du texte : 166...
# [1368] ✅ Texte traduit ajouté au fichier .txt
# [1369] (Paragraphe vide ignoré)
# [1370] Traduction du texte : 167...
# [1370] ✅ Texte traduit ajouté au fichier .txt
# [1371] (Paragraphe vide ignoré)
# [1372] Traduction du texte : 168...
# [1372] ✅ Texte traduit ajouté au fichier .txt
# [1373] (Paragraphe vide ignoré)
# [1374] Traduction du texte : 169...
# [1374] ✅ Texte traduit ajouté au fichier .txt
# [1375] (Paragraphe vide ignoré)
# [1376] Traduction du texte : " La seule forme de pensée économique qui soit con...
# [1376] ✅ Texte traduit ajouté au fichier .txt
# [1377] Traduction du texte : Sur cette conviction forte et politiquement incorr...
# [1377] ✅ Texte traduit ajouté au fichier .txt
# [1378] Traduction du texte : Écrit avec fougue et mordant, Un libéral nommé Jés...
# [1378] ✅ Texte traduit ajouté au fichier .txt
# [1379] Traduction du texte : Charles Gave est économiste, entrepreneur et direc...
# [1379] ✅ Texte traduit ajouté au fichier .txt
# [1380] (Paragraphe vide ignoré)
#
# ✅ Le document traduit a été sauvegardé sous : c:\Users\f.gionnane\Documents\Document Processing Projects\PDF Translation\Charles-Gave-Un-Libéral-Nommé-Jésus_es.docx
# 📄 Fichier de prévisualisation disponible ici : c:\Users\f.gionnane\Documents\Document Processing Projects\PDF Translation\Charles-Gave-Un-Libéral-Nommé-Jésus_es_preview.txt
